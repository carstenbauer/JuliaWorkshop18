# %% [markdown]
# https://qojulia.org/documentation/examples/particle-in-harmonic-trap.html
#
# http://www.stochasticlifestyle.com/some-state-of-the-art-packages-in-julia-v1-0/

# %% [markdown]
# # Math

# %% [markdown]
# ### JuMP

# %% [markdown]
# (Not working on 1.0 yet)

# %% [markdown]
# State-of-the-art modelling language (domain specific language) for mathematical optimization (linear, mixed-integer, conic, semidefinite, nonlinear.

# %% [markdown]
# ### LsqFit.jl

# %% [markdown]
# Least square fitting of data to a custom model.

# %%
using LsqFit

# %%
model(x, p) = p[1]*exp.(-x.*p[2]) # f(x) = α*exp(-γ*x)

xdata = linspace(0, 10, 20)
ydata = model(xdata, [1.0 2.0]) + 0.01*randn(length(xdata))
p0 = [0.5, 0.5]

fit = curve_fit(model, xdata, ydata, p0)

fit.param

# define function for fit result
modelfit = x -> model(x, fit.param)
modelfit(0.2)
# Out:
# 0.6603030195089533

# %% [markdown]
# ### ApproxFun.jl

# %%
using ApproxFun

# %%
myfunc(x) = x^3 - 2*x + x^2 - 2*sin(10*x)
f = Fun(myfunc)
# Out:
# Fun(Chebyshev(【-1.0,1.0】),[0.5, -1.42389, 0.5, 0.483518, 1.96958e-17, 0.936246, -2.88609e-17, 0.866844, -1.04175e-17, -1.16742  …  4.60438e-17, 1.1048e-9, -1.39342e-17, -3.61988e-11, -2.32994e-18, 1.02739e-12, 0.0, -2.52996e-14, 2.57069e-18, 9.90183e-16])

# %% [markdown]
# ### Polynomials.jl

# %% [markdown]
# Approximate data by a polynomial to be able to calculate roots, extrema, integrals, etcetera.

# %%
using Polynomials

# %%
myp(x) = 3*x
xdata = -1:.1:1
ydata = myfunc.(xdata);
p = polyfit(xdata, ydata)
# Out:
# Poly(-4.760636329592671e-13 - 21.99999759993608*x + 0.999999999913791*x^2 + 334.3329608441714*x^3 + 7.005207302692887e-9*x^4 - 1666.6507461710623*x^5 - 1.6706464272165978e-7*x^6 + 3967.9599398668156*x^7 + 1.8149244427710258e-6*x^8 - 5508.630672075789*x^9 - 1.0641025398490601e-5*x^10 + 4994.732794653599*x^11 + 3.6279625675568894e-5*x^12 - 3159.321402395326*x^13 - 7.366656379570021e-5*x^14 + 1421.3562542609454*x^15 + 8.734891320306257e-5*x^16 - 426.6285653251695*x^17 - 5.557334566101827e-5*x^18 + 64.93747616353085*x^19 + 1.4597617178244494e-5*x^20)

# %%
using PyPlot
grid = linspace(-1, 1, 100)
plot(grid, p.(grid), label="polynomial")
plot(xdata, ydata, "o", label="data")
legend()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x00000000026B41D0>
# WARNING: both ApproxFun and Polynomials export "roots"; uses of it in module Main must be qualified

# %% [markdown]
# ### Cubature.jl

# %% [markdown]
# (Not working on 1.0 yet)

# %% [markdown]
# One- and multi-dimensional adaptive integration routines for the Julia language

# %% [markdown]
# ### Optim.jl

# %% [markdown]
# ### ReverseDiff.jl and ForwardDiff.jl

# %% [markdown]
# Derivatives, gradients, Jacobians, Hessians, and higher-order derivatives of native Julia functions

# %%
using ForwardDiff

# %%
f1(x::Real)::Real = 3*x^2 + 4
f2(x::Vector)::Real = x[1]+x[2]^2+x[3]^3
f3(x::Vector)::Vector = 3*x.^2 + x[1]*x[2]
f4(x::Matrix)::Real = sum(x*x*x)
# Out:
# f4 (generic function with 1 method)

# %%
d = x -> ForwardDiff.derivative(f1, x); # d = f1'
@show d(2.0);
# Out:
# d(2.0) = 12.0

# %%
using BenchmarkTools
@btime $d(2.0);
# Out:
#   2.133 ns (0 allocations: 0 bytes)

# %%
g = x -> ForwardDiff.gradient(f2, x); # g = ∇f2
@show g([1,2,3]);
# Out:
# g([1, 2, 3]) = [1, 4, 27]

# %%
j = x -> ForwardDiff.jacobian(f3, x); # J(f3)
j([1,2,3])
# Out:
# MethodError: no method matching +(::Array{ForwardDiff.Dual{ForwardDiff.Tag{typeof(f3),Int64},Int64,3},1}, ::ForwardDiff.Dual{ForwardDiff.Tag{typeof(f3),Int64},Int64,3})
# Closest candidates are:
#   +(::Any, ::Any, !Matched::Any, !Matched::Any...) at operators.jl:502
#   +(!Matched::Complex{Bool}, ::Real) at complex.jl:292
#   +(!Matched::Missing, ::Number) at missing.jl:93
#   ...
#
# Stacktrace:
#  [1] f3(::Array{ForwardDiff.Dual{ForwardDiff.Tag{typeof(f3),Int64},Int64,3},1}) at .\In[2]:3
#  [2] vector_mode_dual_eval(::typeof(f3), ::Array{Int64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{typeof(f3),Int64},Int64,3,Array{ForwardDiff.Dual{ForwardDiff.Tag{typeof(f3),Int64},Int64,3},1}}) at C:\Users\carsten\.julia\packages\ForwardDiff\hnKaN\src\apiutils.jl:35
#  [3] vector_mode_jacobian(::typeof(f3), ::Array{Int64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{typeof(f3),Int64},Int64,3,Array{ForwardDiff.Dual{ForwardDiff.Tag{typeof(f3),Int64},Int64,3},1}}) at C:\Users\carsten\.julia\packages\ForwardDiff\hnKaN\src\jacobian.jl:139
#  [4] jacobian(::Function, ::Array{Int64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{typeof(f3),Int64},Int64,3,Array{ForwardDiff.Dual{ForwardDiff.Tag{typeof(f3),Int64},Int64,3},1}}, ::Val{true}) at C:\Users\carsten\.julia\packages\ForwardDiff\hnKaN\src\jacobian.jl:17
#  [5] jacobian(::Function, ::Array{Int64,1}, ::ForwardDiff.JacobianConfig{ForwardDiff.Tag{typeof(f3),Int64},Int64,3,Array{ForwardDiff.Dual{ForwardDiff.Tag{typeof(f3),Int64},Int64,3},1}}) at C:\Users\carsten\.julia\packages\ForwardDiff\hnKaN\src\jacobian.jl:15 (repeats 2 times)
#  [6] (::getfield(Main, Symbol("##7#8")))(::Array{Int64,1}) at .\In[5]:1
#  [7] top-level scope at In[5]:2

# %%
h = x -> ForwardDiff.hessian(f4, x); # H(f4) = J(∇(f4))
h(rand(2,2))
# Out:
# 4×4 Array{Float64,2}:
#  4.13611  4.08066  1.98967   1.20279
#  4.08066  1.89978  5.23326   4.44637
#  1.98967  5.23326  0.505793  2.35539
#  1.20279  4.44637  2.35539   6.3304

# %% [markdown]
# ### FFTW.jl

# %%
using FFTW

# %%
x = [4,3,2,1,0,1,2,3]
y = rfft(x)
# Out:
# 5-element Array{Complex{Float64},1}:
#     16.0+0.0im
#  6.82843+0.0im
#      0.0+0.0im
#  1.17157+0.0im
#      0.0+0.0im

# %% [markdown]
# # Physics

# %% [markdown]
# ### DifferentialEquations.jl

# %% [markdown]
# State-of-the-art package for calculating ODEs, PDEs, SDEs, ...

# %%
using DifferentialEquations

# %% [markdown]
# ### DynamicalSystems.jl

# %%
using DynamicalSystems
# Out:
# INFO: Recompiling stale cache file C:\Users\carsten\.julia\lib\v0.6\DiffEqOperators.ji for module DiffEqOperators.
# INFO: Recompiling stale cache file C:\Users\carsten\.julia\lib\v0.6\DynamicalSystems.ji for module DynamicalSystems.

# %% [markdown]
# ### PeriodicTable.jl

# %%
using PeriodicTable

# %%
elements
# Out:
# Elements(…119 elements…):
# H                                                  He
# Li Be                               B  C  N  O  F  Ne
# Na Mg                               Al Si P  S  Cl Ar
# K  Ca Sc Ti V  Cr Mn Fe Co Ni Cu Zn Ga Ge As Se Br Kr
# Rb Sr Y  Zr Nb Mo Tc Ru Rh Pd Ag Cd In Sn Sb Te I  Xe
# Cs Ba    Hf Ta W  Re Os Ir Pt Au Hg Tl Pb Bi Po At Rn
# Fr Ra    Rf Db Sg Bh Hs Mt Ds Rg Cn Nh Fl Mc Lv Ts Og
# Uue
#       La Ce Pr Nd Pm Sm Eu Gd Tb Dy Ho Er Tm Yb Lu
#       Ac Th Pa U  Np Pu Am Cm Bk Cf Es Fm Md No Lr

# %%
elements["Sodium"] # or elements[:Na] or elements[11]
# Out:
# Sodium (Na), number 11:
#         category: alkali metal
#      atomic mass: 22.989769282 u
#          density: 0.968 g/cm³
#       molar heat: 28.23 J/mol⋅K
#    melting point: 370.944 K
#    boiling point: 1156.09 K
#            phase: Solid
#           shells: [2, 8, 1]
# e⁻-configuration: 1s² 2s² 2p⁶ 3s¹
#       appearance: silvery white metallic
#          summary: Sodium /ˈsoʊdiəm/ is a chemical element with symbol Na (from Ancient Greek Νάτριο) and atomic number 11. It is a soft, silver-white, highly reactive metal. In the Periodic table it is in column 1 (alkali metals), and shares with the other six elements in that column that it has a single electron in its outer shell, which it readily donates, creating a positively charged atom - a cation.
#    discovered by: Humphry Davy
#           source: https://en.wikipedia.org/wiki/Sodium
#   spectral image: https://en.wikipedia.org/wiki/File:Sodium_Spectra.jpg

# %% [markdown]
# ### Measurements.jl

# %% [markdown]
# A package that allows you to define numbers with uncertainties, perform calculations involving them, and easily get the uncertainty of the result according to linear error propagation theory.

# %%
using Measurements

# %%
x = 4 ± 0.1
# Out:
# 4.0 ± 0.1

# %%
typeof(x)
# Out:
# Measurement{Float64}

# %%
y = measurement(5.1, 0.2)
# Out:
# 5.1 ± 0.2

# %%
x + y
# Out:
# 9.1 ± 0.223606797749979

# %%
x * y
# Out:
# 20.4 ± 0.9487360012142473

# %%
1/x # Δ(1/x) = d(1/x)/dx * Δx
# Out:
# 0.25 ± 0.00625

# %% [markdown]
# Some properties to be aware of:

# %%
(3 ± 0.1) === (3 ± 0.1)
# Out:
# false

# %%
(3 ± 0.1) / (3 ± 0.1)
# Out:
# 1.0 ± 0.04714045207910317

# %% [markdown]
# ### Unitful.jl

# %%
using Unitful

# %%
1u"kg"
# Out:
# 1 kg

# %%
unit(1u"kg")
# Out:
# kg

# %%
ustrip(1u"kg") # strip the units
# Out:
# 1

# %%
uconvert(u"g", 1u"kg")
# Out:
# 1000//1

# %%
1u"A" * 2u"Ω" isa Unitful.Voltage
# Out:
# true

# %% [markdown]
# Great, but can we avoid this `u"kg"` notation and make it more natural? Sure!

# %%
using Unitful: ms, s, minute, hr, rad, °, mm, cm, m, km

# %%
t = 1.0s
# Out:
# 1.0 s

# %%
t + 2s
# Out:
# 3.0 s

# %%
2*t
# Out:
# 2.0 s

# %%
t^2
# Out:
# 1.0 s^2

# %%
t + t^2
# Out:
# DimensionError: 1.0 s and 1.0 s^2 are not dimensionally compatible.
#
# Stacktrace:
#  [1] +(::Quantity{Float64,Unitful.Dimensions{(Unitful.Dimension{:Time}(1//1),)},Unitful.FreeUnits{(Unitful.Unit{:Second,Unitful.Dimensions{(Unitful.Dimension{:Time}(1//1),)}}(0, 1//1),),Unitful.Dimensions{(Unitful.Dimension{:Time}(1//1),)}}}, ::Quantity{Float64,Unitful.Dimensions{(Unitful.Dimension{:Time}(2//1),)},Unitful.FreeUnits{(Unitful.Unit{:Second,Unitful.Dimensions{(Unitful.Dimension{:Time}(1//1),)}}(0, 2//1),),Unitful.Dimensions{(Unitful.Dimension{:Time}(2//1),)}}}) at C:\Users\carsten\.julia\packages\Unitful\RG8e9\src\quantities.jl:85
#  [2] top-level scope at In[11]:1

# %% [markdown]
# Note that in Julia using unitful quantities comes with only a minor overhead, in contrast to Python for example. For more information have a look at https://medium.com/@Jernfrost/defining-custom-units-in-julia-and-python-513c34a4c971.

# %% [markdown]
# Domain specific extensions available: [UnitfulAstro.jl](https://github.com/JuliaAstro/UnitfulAstro.jl), [UnitfulUS.jl](https://github.com/ajkeller34/UnitfulUS.jl), [UnitfulAngles.jl](https://github.com/yakir12/UnitfulAngles.jl)

# %% [markdown]
# ### Parameters.jl

# %%
using Parameters

# %%
@with_kw struct MyParams
    x::Int = 4
    y::Float64
end
# Out:
# MyParams

# %%
MyParams()
# Out:
# Field 'y' has no default, supply it with keyword.
#
# Stacktrace:
#  [1] error(::String) at .\error.jl:33
#  [2] MyParams() at C:\Users\carsten\.julia\packages\Parameters\35RKe\src\Parameters.jl:462
#  [3] top-level scope at In[3]:1

# %%
MyParams(y = 2)
# Out:
# MyParams
#   x: Int64 4
#   y: Float64 2.0

# %%
@with_kw struct MyParams2
    x::Int = 4;
    y::Float64 = 5.3
    z::Int = floor(x+y)
end
# Out:
# MyParams2

# %%
MyParams2()
# Out:
# MyParams2
#   x: Int64 4
#   y: Float64 5.3
#   z: Int64 9

# %%
@with_kw struct MyParams3
    x::Int = 4; @assert x != 2
    y::Float64 = 5.3
    @assert x + y >= 9
end
# Out:
# MyParams3

# %%
MyParams3(y = 3)
# Out:
# AssertionError: x + y >= 9
#
# Stacktrace:
#  [1] Type at .\none:0 [inlined]
#  [2] #MyParams3#9 at C:\Users\carsten\.julia\packages\Parameters\35RKe\src\Parameters.jl:462 [inlined]
#  [3] (::getfield(Core, Symbol("#kw#Type")))(::NamedTuple{(:y,),Tuple{Int64}}, ::Type{MyParams3}) at .\none:0
#  [4] top-level scope at In[8]:1

# %%
MyParams3(x = 2)
# Out:
# AssertionError: x != 2
#
# Stacktrace:
#  [1] Type at .\none:0 [inlined]
#  [2] #MyParams3#9 at C:\Users\carsten\.julia\packages\Parameters\35RKe\src\Parameters.jl:462 [inlined]
#  [3] (::getfield(Core, Symbol("#kw#Type")))(::NamedTuple{(:x,),Tuple{Int64}}, ::Type{MyParams3}) at .\none:0
#  [4] top-level scope at In[9]:1

# %%
@with_kw mutable struct MyParams4 @deftype Int
    x = 4;
    y::Float64 = 5.3
    z = floor(x+y)
    a = 1
    b = 2
end
# Out:
# MyParams4

# %% [markdown]
# **unpack and pack**

# %%
p = MyParams4()

@unpack x,z = p;
@show x, z

# is equivalent to
# a = p.a
# c = p.c
# Out:
# (x, z) = (4, 9)

# %%
x = 1
@pack! p = x

p
# Out:
# MyParams4
#   x: Int64 1
#   y: Float64 5.3
#   z: Int64 9
#   a: Int64 1
#   b: Int64 2

# %% [markdown]
# ### QuantumOptics.jl

# %%
using QuantumOptics

# %% [markdown]
# # Data science / Statistics

# %% [markdown]
# ### DataFrames.jl

# %% [markdown]
# (and DataFramesMeta.jl)

# %% [markdown]
# ### Query.jl

# %% [markdown]
# ### Distributions.jl

# %% [markdown]
# ### StatsBase.jl

# %% [markdown]
# ### CSV.jl

# %% [markdown]
# ### OnlineStats.jl

# %% [markdown]
# # Computer science

# %% [markdown]
# ### LightGraphs.jl

# %% [markdown]
# ### DataStructures.jl

# %% [markdown]
# ### CUDAnative.jl

# %% [markdown]
# Native GPU programming

# %% [markdown]
# # Machine learning

# %% [markdown]
# ### Flux.jl

# %% [markdown]
# ### Knet.jl

# %% [markdown]
# ### (TensorFlow.jl)

# %% [markdown]
# ### (MXNet.jl)

# %% [markdown]
# ### (ScikitLearn.jl)

# %% [markdown]
# ### LightML.jl

# %% [markdown]
# Minimal and clean examples of machine learning algorithms implemented in Julia

# %% [markdown]
# # Plotting and Graphics

# %% [markdown]
# ### PyPlot.jl

# %% [markdown]
# Wrapper to matplotlib (based on PyCall.jl)

# %%
using PyPlot

# %%
x = -2π:0.1:2π
y = sin.(x)

plot(x,y);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# It is matplotlib, so you know how to use it!

# %%
figure(figsize=(6,4))
plot(x,y, "ro--", label="My sine!")
xlabel("x")
ylabel("y(x)")
title("It is a sine!");
legend();
# Out:
# Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %% [markdown]
# ### Plots.jl

# %% [markdown]
# Plotting "front-end" for multiple backends (gr, pyplot, plotlyjs, pgfplotx)

# %% [markdown]
# ### UnicodePlots.jl

# %%
using UnicodePlots

# %%
myPlot = lineplot([cos, sin], -π/2, 2π)
# Out:
#            ┌────────────────────────────────────────┐
#          1 │⠀⠀⠀⠀⠀⠀⢀⠖⢹⠉⢢⠀⠀⢀⠞⠉⠉⢢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠞⠉⠀⠀⠀│ cos(x)
#            │⠀⠀⠀⠀⠀⢠⠊⠀⢸⠀⠀⠳⣠⠊⠀⠀⠀⠀⠣⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⠃⠀⠀⠀⠀⠀│ sin(x)
#            │⠀⠀⠀⠀⢀⠇⠀⠀⢸⠀⠀⢠⢷⠀⠀⠀⠀⠀⠀⢱⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⠇⠀⠀⠀⠀⠀⠀│
#            │⠀⠀⠀⠀⡜⠀⠀⠀⢸⠀⠀⡜⠀⢧⠀⠀⠀⠀⠀⠀⢧⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀⠀⠀│
#            │⠀⠀⠀⢸⠀⠀⠀⠀⢸⠀⢸⠀⠀⠘⡄⠀⠀⠀⠀⠀⠘⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⠀⠀│
#            │⠀⠀⢀⠇⠀⠀⠀⠀⢸⢀⠇⠀⠀⠀⢱⠀⠀⠀⠀⠀⠀⢱⠀⠀⠀⠀⠀⠀⠀⠀⢠⠃⠀⠀⠀⠀⠀⠀⠀⠀│
#            │⠀⠀⡜⠀⠀⠀⠀⠀⢸⡜⠀⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠀⠀⡜⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#    f(x)    │⠤⠤⠧⠤⠤⠤⠤⠤⢼⠧⠤⠤⠤⠤⠤⠼⡤⠤⠤⠤⠤⠤⠼⡤⠤⠤⠤⠤⠤⢴⠥⠤⠤⠤⠤⠤⢤⠤⠤⠄│
#            │⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⢣⠀⠀⠀⠀⠀⠀⢣⠀⠀⠀⠀⢀⠇⠀⠀⠀⠀⠀⢀⠇⠀⠀⠀│
#            │⠀⠀⠀⠀⠀⠀⠀⡸⢸⠀⠀⠀⠀⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠈⡆⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀⡸⠀⠀⠀⠀│
#            │⠀⠀⠀⠀⠀⠀⢀⠇⢸⠀⠀⠀⠀⠀⠀⠀⠀⢱⠀⠀⠀⠀⠀⠀⢱⠀⠀⢠⠃⠀⠀⠀⠀⠀⢠⠃⠀⠀⠀⠀│
#            │⠀⠀⠀⠀⠀⠀⡞⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⢇⠀⠀⠀⠀⠀⠀⢇⠀⡞⠀⠀⠀⠀⠀⠀⡎⠀⠀⠀⠀⠀│
#            │⠀⠀⠀⠀⠀⡸⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⡆⠀⠀⠀⠀⠀⠘⡾⠀⠀⠀⠀⠀⠀⡸⠀⠀⠀⠀⠀⠀│
#            │⠀⠀⠀⠀⡰⠁⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢄⠀⠀⠀⠀⡜⠙⣄⠀⠀⠀⠀⡜⠁⠀⠀⠀⠀⠀⠀│
#         -1 │⠀⢀⣀⠜⠀⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢦⣀⣀⠜⠀⠀⠈⢦⣀⣠⠜⠀⠀⠀⠀⠀⠀⠀⠀│
#            └────────────────────────────────────────┘
#            -2                                       7
#                                x

# %% [markdown]
# ### (Makie.jl)

# %% [markdown]
# Not really usable yet. Probably the future of native Julia plotting.

# %% [markdown]
# ### Luxor.jl

# %% [markdown]
# ### Images.jl

# %% [markdown]
# # Other

# %% [markdown]
# ### Revise.jl

# %% [markdown]
# ### ProfileView.jl

# %% [markdown]
# At the time of writing, `] add Gtk#master` was necessary.

# %% [markdown]
# ### TimerOutputs.jl

# %%
using TimerOutputs

# %%
to = TimerOutput();

@timeit to "initialization" A = rand(3,3)

@timeit to "calculation" begin
    @timeit to "part 1" B = A'
    @timeit to "part 2" B*B
end

to
# Out:
#  ─────────────────────────────────────────────────────────────────────────
#                                   Time                   Allocations
#                           ──────────────────────   ───────────────────────
#      Tot / % measured:         701ms / 67.5%           56.9MiB / 77.8%
#
#  Section          ncalls     time   %tot     avg     alloc   %tot      avg
#  ─────────────────────────────────────────────────────────────────────────
#  calculation           1    464ms  98.2%   464ms   43.5MiB  98.3%  43.5MiB
#    part 2              1    454ms  96.1%   454ms   43.0MiB  97.1%  43.0MiB
#    part 1              1   9.84ms  2.08%  9.84ms    553KiB  1.22%   553KiB
#  initialization        1   8.62ms  1.82%  8.62ms    760KiB  1.68%   760KiB
#  ─────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ### Rebugger.jl (only Julia 1.0)

# %% [markdown]
# An expression-level debugger for Julia with a provocative command-line (REPL) user interface.
#
# In terms of usage, very briefly
#
# * "step in" is achieved by positioning your cursor in your input line to the beginning of the call expression you wish to descend into. Then hit Meta-e  ("enter").
# * for an expression that generates an error, hit Meta-s  ("stacktrace") to capture the stacktrace and populate your REPL history with a sequence of expressions that contain the method bodies of the calls in the stacktrace.
#
# Meta  means Esc  or, if your system is configured appropriately, Alt  (Linux/Windows) or Option  (Macs).

# %% [markdown]
# Demonstration in the REPL...

# %% [markdown]
# ### EllipsisNotation.jl

# %%
using EllipsisNotation

# %%
A = rand(1,2,3,4,5,6);

# %%
A[..,3] == A[:,:,:,:,:,3]
# Out:
# true

# %%
A[1,..,3] == A[1,:,:,:,:,3]
# Out:
# true

# %% [markdown]
# ### ProgressMeter.jl

# %%
using ProgressMeter

# %%
@showprogress .5 for i in 1:20
    sleep(rand())
end

# %% [markdown]
# ### OhMyREPL.jl

# %% [markdown]
# Syntax highlighting for the REPL

# %% [markdown]
# ### Latexify.jl

# %% [markdown]
# # Data formats

# %% [markdown]
# ### HDF5.jl

# %%
using HDF5

# %%
A = rand(2,3)
# Out:
# 2×3 Array{Float64,2}:
#  0.996711  0.0955898  0.3628
#  0.831186  0.333382   0.504056

# %%
h5write("test.h5", "A", A)
# Out:
# UndefVarError: h5write not defined
#
# Stacktrace:
#  [1] top-level scope at In[16]:1

# %%
Aloaded = h5read("test.h5", "A")
# Out:
# 2×3 Array{Float64,2}:
#  0.996711  0.0955898  0.3628
#  0.831186  0.333382   0.504056

# %% [markdown]
# If one wants to read/write multiple things at once one can do that like so:

# %%
# r = read existing file
# r+ = read and write existing file
# w = overwrite existing / create new file
h5open("test.h5", "r+") do f
    for k in 1:5
        f[string(k)] = rand(2,2)
        # or write(f, string(k), rand(2,2))
    end
end

# %%
f = h5open("test.h5", "r+")
# Out:
# HDF5 data file: test.h5

# %%
names(f)
# Out:
# 6-element Array{String,1}:
#  "1"
#  "2"
#  "3"
#  "4"
#  "5"
#  "A"

# %%
f["A"]
# Out:
# HDF5 dataset: /A (file: test.h5xfer_mode: 0 )

# %%
read(f["A"])
# Out:
# 2×3 Array{Float64,2}:
#  0.996711  0.0955898  0.3628
#  0.831186  0.333382   0.504056

# %% [markdown]
# HDF5 is nice and fine. It is supported by practically every programming language. However, some things are annoyingly complicated. For example, one can't just overwrite a dataset. Instead one has to check whether this dataset already exists, delete it if so, and then create a new dataset.

# %%
h5open("test.h5", "r+") do f
    HDF5.has(f, "A") && o_delete(f, "A")
    f["A"] = rand(2, 2)
end

# %% [markdown]
# Also, one can only store basic types like Float64, Int64, etc. (in an easy way)

# %%
C = rand(ComplexF64, 2, 2)
h5write("test.h5", "C", C)
# Out:
# MethodError: no method matching write(::HDF5File, ::String, ::Array{Complex{Float64},2})
# Closest candidates are:
#   write(::Union{HDF5File, HDF5Group}, ::String, ::Any, !Matched::String, !Matched::Any, !Matched::Any...) at C:\Users\carsten\.julia\packages\HDF5\b6QoH\src\HDF5.jl:1627
#   write(!Matched::AbstractString, ::Any, ::Any...) at io.jl:283
#   write(!Matched::IO, ::Any, ::Any...) at io.jl:500
#   ...
#
# Stacktrace:
#  [1] h5write(::String, ::String, ::Array{Complex{Float64},2}) at C:\Users\carsten\.julia\packages\HDF5\b6QoH\src\HDF5.jl:720
#  [2] top-level scope at In[153]:2

# %%
close(f);
rm("test.h5");

# %% [markdown]
# ### JLD2.jl

# %% [markdown]
# HDF5 based but can story arbitrary Julia objects. (Predecessor JLD.jl not working on 1.0 yet)

# %%
using JLD2

# %%
A = rand(2,3)
# Out:
# 2×3 Array{Float64,2}:
#  0.91899   0.125984  0.676983
#  0.709554  0.388086  0.584184

# %%
@save "test.jld2" A

# %%
B = rand(2,3)
# Out:
# 2×3 Array{Float64,2}:
#  0.644377  0.657205  0.0572491
#  0.565712  0.390731  0.160103

# %%
@save "test.jld2" B # overwrites(!) test.jld2 file

# %%
@load "test.jld2" B # will load dataset "B" automatically to variable B
# Out:
# 1-element Array{Symbol,1}:
#  :B

# %% [markdown]
# To get more control, one can open/close the file as for HDF5:

# %%
jldopen("test.jld2", "r+") do f
    @show f["B"] # no read necessary
    @show f["C"] = rand(ComplexF64, 2, 2); # can store arbitrary Julia objects
end;
# Out:
# f["B"] = [0.644377 0.657205 0.0572491; 0.565712 0.390731 0.160103]
# f["C"] = rand(ComplexF64, 2, 2) = Complex{Float64}[0.463698+0.745836im 0.733641+0.433613im; 0.49924+0.313831im 0.527326+0.161852im]

# %%
@load "test.jld2" # loads everything from file to variables
# Out:
# 2-element Array{Symbol,1}:
#  :B
#  :C

# %%
C
# Out:
# 2×2 Array{Complex{Float64},2}:
#  0.463698+0.745836im  0.733641+0.433613im
#   0.49924+0.313831im  0.527326+0.161852im

# %%
# clean up
rm("test.jld2")

# %% [markdown]
# ### NPZ.jl

# %% [markdown]
# Reading and writing numpy files.

# %%
using NPZ

# %%
A = rand(2,2)
# Out:
# 2×2 Array{Float64,2}:
#  0.180294  0.022668
#  0.943385  0.550827

# %%
npzwrite("test.npz", A)

# %%
Aloaded = npzread("test.npz")
# Out:
# 2×2 Array{Float64,2}:
#  0.180294  0.022668
#  0.943385  0.550827

# %% [markdown]
# Let's actually load the file with numpy

# %%
using PyCall
@pyimport numpy as np

# %%
np.load("test.npz")
# Out:
# 2×2 Array{Float64,2}:
#  0.180294  0.022668
#  0.943385  0.550827

# %%
# clean up
rm("test.npz")

# %% [markdown]
# ### MAT.jl

# %% [markdown]
# Reading and writing MATLAB files

# %% [markdown]
# # Arrays, matrices, and tensors

# %% [markdown]
# See https://github.com/JuliaArrays. The most important ones are:

# %% [markdown]
# ### StaticArrays.jl

# %%
using StaticArrays

# %%
m = SMatrix{2,2}(1, 2, 3, 4)
# Out:
# 2×2 SArray{Tuple{2,2},Int64,2,4}:
#  1  3
#  2  4

# %%
size(m)
# Out:
# (2, 2)

# %%
size(typeof(m))
# Out:
# (2, 2)

# %%
# compare to
M = Matrix(m)
size(typeof(M))
# Out:
# MethodError: no method matching size(::Type{Array{Int64,2}})
# Closest candidates are:
#   size(!Matched::BitArray{1}) at bitarray.jl:70
#   size(!Matched::BitArray{1}, !Matched::Any) at bitarray.jl:74
#   size(!Matched::Core.Compiler.StmtRange) at show.jl:1561
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[24]:3

# %%
m2 = @SMatrix [ 1  3 ;
                2  4 ]
# Out:
# 2×2 SArray{Tuple{2,2},Int64,2,4}:
#  1  3
#  2  4

# %%
m3 = @SMatrix rand(4,4)
# Out:
# 4×4 SArray{Tuple{4,4},Float64,2,16}:
#  0.278213  0.455851  0.336642  0.154724
#  0.534905  0.333391  0.588661  0.754726
#  0.142001  0.879145  0.650837  0.343375
#  0.371889  0.748404  0.112358  0.272267

# %%
a = @SArray randn(2, 2, 2)
# Out:
# 2×2×2 SArray{Tuple{2,2,2},Float64,3,8}:
# [:, :, 1] =
#  -0.892293  1.80155
#   0.872782  1.2959
#
# [:, :, 2] =
#  0.0617252  0.751006
#  0.813146   0.175316

# %% [markdown]
# ** Static arrays are fast ... **

# %%
using BenchmarkTools, LinearAlgebra

# %%
println("Inversion")
@btime inv($m);
@btime inv($M);
# Out:
# Inversion
#   11.520 ns (0 allocations: 0 bytes)
#   665.815 ns (6 allocations: 1.50 KiB)

# %%
println("Matrix x vector")
v = rand(2)
@btime $m * $v;
@btime $M * $v;
# Out:
# Matrix x vector
#   6.400 ns (0 allocations: 0 bytes)
#   49.563 ns (1 allocation: 96 bytes)

# %% [markdown]
# *Benchmarks for 3×3 Float64 matrices:*
#
# | Operation | Speedup |
# | --- | --- |
# | Matrix multiplication | 8.2x |
# | Matrix multiplication (mutating)    | 3.1x |
# | Matrix addition                     | 45x |
# | Matrix addition (mutating)          | 5.1x |
# | Matrix determinant                  | 170x |
# | Matrix inverse                      | 125x |
# | Matrix symmetric eigendecomposition | 82x |
# | Matrix Cholesky decomposition       | 23.6x |

# %% [markdown]
# ** ... as long as they are not too large ** because they put a lot of stress on the compiler!

# %%
# takes a long time to compile and is slower
N = 50
M = rand(N,N);
v = rand(N);
m = SMatrix{N,N}(M);

println("Inversion")
@btime inv($m);
@btime inv($M);

println("Matrix x vector")
@btime $m * $v;
@btime $M * $v;
# Out:
# Inversion
#   288.854 μs (8 allocations: 65.00 KiB)
#   281.173 μs (6 allocations: 45.36 KiB)
# Matrix x vector
#   1.195 μs (0 allocations: 0 bytes)
#   497.409 ns (1 allocation: 544 bytes)

# %% [markdown]
# ### BlockArrays.jl

# %% [markdown]
# ### DistributedArrays.jl

# %% [markdown]
# ### BandedMatrices.jl and BlockBandedMatrices.jl

# %% [markdown]
# ### GPUArrays.jl, CuArrays.jl, CLArrays.jl

# %% [markdown]
# ### Tensor.jl and TensorOperations.jl
